# %%
from gtoa.utils import  run_experiments, plot_results, plot_line_results, plot_surface_results, plot_results_logscale

# %%
N = [10, 20, 40, 80]
I = [5, 10, 20, 40, 60, 80]

df = run_experiments(N_values=N, I_values=I,
                         Tmax=5000, n_repeats=1, seed=12345, verbose=False)
# Out:
# === Funkcja testowa: Sphere ===
# N=10, I=5 → minimum=1.1052e-04, najgorsze=1.1052e-04, val_cv=0.0, val_std=0.0
# N=10, I=10 → minimum=9.7779e-09, najgorsze=9.7779e-09, val_cv=nan, val_std=0.0
# N=10, I=20 → minimum=5.1650e-17, najgorsze=5.1650e-17, val_cv=nan, val_std=0.0
# N=10, I=40 → minimum=8.2105e-34, najgorsze=8.2105e-34, val_cv=nan, val_std=0.0
# N=10, I=60 → minimum=1.1732e-49, najgorsze=1.1732e-49, val_cv=nan, val_std=0.0
# N=10, I=80 → minimum=3.5032e-66, najgorsze=3.5032e-66, val_cv=nan, val_std=0.0
# N=20, I=5 → minimum=4.9093e-04, najgorsze=4.9093e-04, val_cv=0.0, val_std=0.0
# N=20, I=10 → minimum=1.7375e-08, najgorsze=1.7375e-08, val_cv=0.0, val_std=0.0
# N=20, I=20 → minimum=6.7097e-17, najgorsze=6.7097e-17, val_cv=nan, val_std=0.0
# N=20, I=40 → minimum=1.0974e-33, najgorsze=1.0974e-33, val_cv=nan, val_std=0.0
# N=20, I=60 → minimum=1.1170e-49, najgorsze=1.1170e-49, val_cv=nan, val_std=0.0
# ...

# %%
plot_results(df, "Sphere")

# %%
plot_results(df, "Rosenbrock")

# %%
plot_line_results(df, "Rosenbrock")

# %%
plot_surface_results(df, "Rosenbrock")

# %%
plot_results_logscale(df, "Rosenbrock")
