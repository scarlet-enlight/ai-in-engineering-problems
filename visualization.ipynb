# %%
from gtoa.utils import  run_experiments, plot_results

# %%
N = [10, 20, 40, 80]
I = [5, 10, 20, 40, 60, 80, 5000]

df = run_experiments(N_values=N, I_values=I,
                         Tmax=5000, n_repeats=1, seed=12345, verbose=False)
# Out:
# === Funkcja testowa: Sphere ===
# N=10, I=5 → minimum=7.9561e-02, najgorsze=7.9561e-02, val_cv=0.0, val_std=0.0
# N=10, I=10 → minimum=3.0096e-06, najgorsze=3.0096e-06, val_cv=0.0, val_std=0.0
# N=10, I=20 → minimum=2.8262e-12, najgorsze=2.8262e-12, val_cv=nan, val_std=0.0
# N=10, I=40 → minimum=1.2062e-26, najgorsze=1.2062e-26, val_cv=nan, val_std=0.0
# N=10, I=60 → minimum=7.0859e-40, najgorsze=7.0859e-40, val_cv=nan, val_std=0.0
# N=10, I=80 → minimum=4.0011e-51, najgorsze=4.0011e-51, val_cv=nan, val_std=0.0
# N=10, I=5000 → minimum=3.9642e-152, najgorsze=3.9642e-152, val_cv=nan, val_std=0.0
# N=20, I=5 → minimum=7.4467e-02, najgorsze=7.4467e-02, val_cv=0.0, val_std=0.0
# N=20, I=10 → minimum=6.0032e-06, najgorsze=6.0032e-06, val_cv=0.0, val_std=0.0
# N=20, I=20 → minimum=1.3011e-13, najgorsze=1.3011e-13, val_cv=nan, val_std=0.0
# N=20, I=40 → minimum=1.6399e-25, najgorsze=1.6399e-25, val_cv=nan, val_std=0.0
# ...

# %%
plot_results(df, "Sphere")

# %%
plot_results(df, "Bukin")

# %%
plot_results(df, "Rastrigin")

# %%
plot_results(df, "Rosenbrock")
