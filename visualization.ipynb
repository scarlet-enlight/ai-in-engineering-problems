# %%
from gtoa.utils import  run_experiments, plot_results, plot_line_results, plot_surface_results, plot_results_logscale

# %%
N = [500, 3000]
I = [100, 1000, 10000]

df = run_experiments(N_values=N, I_values=I,
                         Tmax=5000, n_repeats=1, seed=12345, verbose=False)
# Out:
# === Funkcja testowa: Sphere ===
# N=500, I=1000 → minimum=2.6956e-08, najgorsze=2.6956e-08, val_cv=0.0, val_std=0.0
# N=3000, I=1000 → minimum=1.4531e-04, najgorsze=1.4531e-04, val_cv=0.0, val_std=0.0
#
# === Funkcja testowa: Rastrigin ===
# N=500, I=1000 → minimum=7.8420e-04, najgorsze=7.8420e-04, val_cv=0.0, val_std=0.0
# N=3000, I=1000 → minimum=1.7505e-01, najgorsze=1.7505e-01, val_cv=0.0, val_std=0.0
#
# === Funkcja testowa: Rosenbrock ===
# N=500, I=1000 → minimum=1.7980e+00, najgorsze=1.7980e+00, val_cv=0.0, val_std=0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 4
#       1 N = [500, 3000]
#       2 I = [1000]
# ----> 4 df = run_experiments(N_values=N, I_values=I,
#       5                          Tmax=5000, n_repeats=1, seed=12345, verbose=False)
#
# File c:\Users\blaze\Documents\GitHub\ai-in-engineering-problems\gtoa\utils.py:46, in run_experiments(N_values, I_values, Tmax, n_repeats, seed, verbose)
#      44 sols = []
#      45 for r in range(n_repeats):
# ---> 46     res = run_single_experiment(func, bounds, func_dim, N, I, Tmax, seed + r, verbose)
#      47     vals.append(res["best_val"])
#      48     sols.append(res["best_x"])
#
# File c:\Users\blaze\Documents\GitHub\ai-in-engineering-problems\gtoa\utils.py:11, in run_single_experiment(func, bounds, dim, N, I, Tmax, seed, verbose)
#       9 def run_single_experiment(func, bounds, dim, N, I, Tmax, seed, verbose=False):
#      10     opt = GTOA(func, dim, bounds, population_size=N, Tmax=Tmax, seed=seed)
# ---> 11     best_x, best_val, Tused, iters, T_hist, best_hist = opt.optimize(verbose=verbose, iter_limit=I)
#      12     return {
#      13         "best_x": best_x,
#      14         "best_val": best_val,
#      15         "T_hist": T_hist,
#      16         "best_hist": best_hist
#      17     }
#
# File c:\Users\blaze\Documents\GitHub\ai-in-engineering-problems\gtoa\algorithm.py:148, in GTOA.optimize(self, verbose, iter_limit)
#     146 # Step 6.2: teacher phase for bad and student-phase for bad (Eq.5, Eq.7-8)
#     147 self.teacher_phase_bad(T, bad_idx)
# --> 148 self.student_phase(bad_idx, X_before_teacher)
#     149 # Step 8: re-evaluate population (Eq.13 block accounting)
#     150 for i in range(self.N):
#
# File c:\Users\blaze\Documents\GitHub\ai-in-engineering-problems\gtoa\algorithm.py:109, in GTOA.student_phase(self, group_idx, X_before_teacher)
#     107 peers = list(range(self.N))
#     108 peers.remove(idx)
# --> 109 j = int(self.rng.choice(peers))
#     110 e = self.rng.random()
#     111 g = self.rng.random()
#
# KeyboardInterrupt:

# %%
plot_results(df, "Sphere")

# %%
plot_results(df, "Rosenbrock")

# %%
plot_line_results(df, "Rosenbrock")

# %%
plot_surface_results(df, "Rosenbrock")

# %%
plot_results_logscale(df, "Rosenbrock")
