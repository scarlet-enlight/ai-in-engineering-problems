# %%
import os

from test_functions import TEST_FUNCTIONS
from utils import run_experiment, plot_convergence

# %%
# Parameters (specified in the acrticle)
D = 10                    # Dimension
POP_SIZE = 50             # N = 50 (in the article)
RUNS = 10                 # Number of independent runs (the article uses 30)
TMAX = 5000 * D           # Tmax = 5000 * D for unimodal

# Other parameters
EPS_LOG = 1e-800          # Clipping before log10 (to avoid receiving -inf)
SAVE_DIR = "gtoa_results" # Directory for csv saving csv and plot

# %% [markdown]
# Sphere

# %%
problem = TEST_FUNCTIONS["Sphere"]
D = 10

T_axis, mean_best, std_best, log10_mean, csv_path = run_experiment(
    problem["fn"],
    problem["bounds"],
    runs=RUNS,
    pop=POP_SIZE,
    D=D,
    Tmax=TMAX,
    seed_base=0,
    save_dir=SAVE_DIR,
    verbose=False
)
# Out:
# c:\Studia (aktualne)\Programowanie objektowe i graficzne\Projekty\ai-in-engineering-problems\gtoa\utils.py:79: RuntimeWarning: divide by zero encountered in log10
#   log10_mean = np.log10(np.maximum(mean_best, EPS_LOG))

# %%
png_path = plot_convergence(T_axis, log10_mean, save_dir=SAVE_DIR)

# %% [markdown]
# Rastrigin

# %%
problem = TEST_FUNCTIONS["Rastrigin"]
D = 10

T_axis, mean_best, std_best, log10_mean, csv_path = run_experiment(
    problem["fn"],
    problem["bounds"],
    runs=RUNS,
    pop=POP_SIZE,
    D=D,
    Tmax=TMAX,
    seed_base=0,
    save_dir=SAVE_DIR,
    verbose=False
)

# %%
png_path = plot_convergence(T_axis, log10_mean, save_dir=SAVE_DIR)

# %% [markdown]
# Rosenbrock

# %%
problem = TEST_FUNCTIONS["Rosenbrock"]
D = 2

T_axis, mean_best, std_best, log10_mean, csv_path = run_experiment(
    problem["fn"],
    problem["bounds"],
    runs=RUNS,
    pop=POP_SIZE,
    D=D,
    Tmax=TMAX,
    seed_base=0,
    save_dir=SAVE_DIR,
    verbose=False
)

# %%
png_path = plot_convergence(T_axis, log10_mean, save_dir=SAVE_DIR)

# %% [markdown]
# BukinN6

# %%
problem = TEST_FUNCTIONS["BukinN6"]
D = 2

T_axis, mean_best, std_best, log10_mean, csv_path = run_experiment(
    problem["fn"],
    problem["bounds"],
    runs=RUNS,
    pop=POP_SIZE,
    D=D,
    Tmax=TMAX,
    seed_base=0,
    save_dir=SAVE_DIR,
    verbose=False
)

# %%
png_path = plot_convergence(T_axis, log10_mean, save_dir=SAVE_DIR)

# %% [markdown]
# Beale

# %%
problem = TEST_FUNCTIONS["Beale"]
D = 2

T_axis, mean_best, std_best, log10_mean, csv_path = run_experiment(
    problem["fn"],
    problem["bounds"],
    runs=RUNS,
    pop=POP_SIZE,
    D=D,
    Tmax=TMAX,
    seed_base=0,
    save_dir=SAVE_DIR,
    verbose=False
)

# %%
png_path = plot_convergence(T_axis, log10_mean, save_dir=SAVE_DIR)
