# %%
from gtoa.utils import  run_experiments, plot_results

# %%
N = [10, 20, 40, 80]
I = [5, 10, 20, 40, 60, 80, 5000]

df = run_experiments(N_values=N, I_values=I,
                         Tmax=5000, n_repeats=1, seed=12345, verbose=False)
# Out:
# === Funkcja testowa: Rosenbrock ===
# N=10, I=5 → minimum=9.4932e+00, najgorsze=9.4932e+00, val_cv=0.0, val_std=0.0
# N=10, I=10 → minimum=8.9796e+00, najgorsze=8.9796e+00, val_cv=0.0, val_std=0.0
# N=10, I=20 → minimum=8.9656e+00, najgorsze=8.9656e+00, val_cv=0.0, val_std=0.0
# N=10, I=40 → minimum=8.9601e+00, najgorsze=8.9601e+00, val_cv=0.0, val_std=0.0
# N=10, I=60 → minimum=8.9600e+00, najgorsze=8.9600e+00, val_cv=0.0, val_std=0.0
# N=10, I=80 → minimum=8.9593e+00, najgorsze=8.9593e+00, val_cv=0.0, val_std=0.0
# N=10, I=5000 → minimum=8.9591e+00, najgorsze=8.9591e+00, val_cv=0.0, val_std=0.0
# N=20, I=5 → minimum=9.7227e+00, najgorsze=9.7227e+00, val_cv=0.0, val_std=0.0
# N=20, I=10 → minimum=8.9058e+00, najgorsze=8.9058e+00, val_cv=0.0, val_std=0.0
# N=20, I=20 → minimum=8.8742e+00, najgorsze=8.8742e+00, val_cv=0.0, val_std=0.0
# N=20, I=40 → minimum=8.8716e+00, najgorsze=8.8716e+00, val_cv=0.0, val_std=0.0
# N=20, I=60 → minimum=8.8704e+00, najgorsze=8.8704e+00, val_cv=0.0, val_std=0.0
# N=20, I=80 → minimum=8.8704e+00, najgorsze=8.8704e+00, val_cv=0.0, val_std=0.0
# N=20, I=5000 → minimum=8.8704e+00, najgorsze=8.8704e+00, val_cv=0.0, val_std=0.0
# N=40, I=5 → minimum=9.0055e+00, najgorsze=9.0055e+00, val_cv=0.0, val_std=0.0
# N=40, I=10 → minimum=8.9336e+00, najgorsze=8.9336e+00, val_cv=0.0, val_std=0.0
# N=40, I=20 → minimum=8.8755e+00, najgorsze=8.8755e+00, val_cv=0.0, val_std=0.0
# N=40, I=40 → minimum=8.8719e+00, najgorsze=8.8719e+00, val_cv=0.0, val_std=0.0
# N=40, I=60 → minimum=8.8711e+00, najgorsze=8.8711e+00, val_cv=0.0, val_std=0.0
# N=40, I=80 → minimum=8.8711e+00, najgorsze=8.8711e+00, val_cv=0.0, val_std=0.0
# N=40, I=5000 → minimum=8.8711e+00, najgorsze=8.8711e+00, val_cv=0.0, val_std=0.0
# N=80, I=5 → minimum=8.9805e+00, najgorsze=8.9805e+00, val_cv=0.0, val_std=0.0
# N=80, I=10 → minimum=8.8906e+00, najgorsze=8.8906e+00, val_cv=0.0, val_std=0.0
# N=80, I=20 → minimum=8.8587e+00, najgorsze=8.8587e+00, val_cv=0.0, val_std=0.0
# N=80, I=40 → minimum=8.8487e+00, najgorsze=8.8487e+00, val_cv=0.0, val_std=0.0
# N=80, I=60 → minimum=8.8487e+00, najgorsze=8.8487e+00, val_cv=0.0, val_std=0.0
# N=80, I=80 → minimum=8.8487e+00, najgorsze=8.8487e+00, val_cv=0.0, val_std=0.0
# N=80, I=5000 → minimum=8.8487e+00, najgorsze=8.8487e+00, val_cv=0.0, val_std=0.0
#
# 📊 Wyniki zapisano do results_summary.csv

# %%
plot_results(df, "Rosenbrock")
